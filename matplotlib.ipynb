# %%
from  matplotlib import pyplot as plt
import pandas as pd

# %% [markdown]
# * Get data currency btc  from file csv and mad first colum is index then transition dtype index to datetime

# %%
df = pd.read_csv(r"path\BTCUSDT.csv",index_col=0,)
df.set_index(pd.to_datetime(df.index),inplace=True)
df
# Out:
#             Unnamed: 0      Open      High       Low     Close        Volume
# Date
# 2022-08-29         0.0  19555.61  20576.25  19540.00  20000.30  3.059723e+10
# 2022-09-05         1.0  20000.30  21860.00  18510.77  21826.87  4.346005e+10
# 2022-09-12         2.0  21826.87  22799.00  19320.01  19416.18  4.578415e+10
# 2022-09-19         3.0  19417.45  19956.00  18125.98  18807.38  4.348805e+10
# 2022-09-26         4.0  18809.13  20385.86  18471.28  19056.80  5.376117e+10
# ...                ...       ...       ...       ...       ...           ...
# 2024-02-19         NaN  52137.68  52985.00  50521.00  51728.85  1.151959e+10
# 2024-02-26         NaN  51728.85  64000.00  50901.44  63113.97  2.488479e+10
# 2024-03-04         NaN  63113.97  69990.00  59005.00  68955.88  3.204890e+10
# 2024-03-11         NaN  68955.88  73777.00  64533.00  68393.48  3.340111e+10
# 2024-03-18         NaN  68393.47  68956.00  62410.78  64093.12  9.745408e+09
#
# [83 rows x 6 columns]

# %% [markdown]
# # plot Volume price  from (2024-01-01) to (2024-03-18) .
# * I mad changes figure size to (14,5) , line volume red and add marker "." to slope angle add line kind of grid to chart by function grid ,and style appearance grid lines : label color  red  by parameter  abelcolor  and leble size medium and sold = 3 by parameter width

# %%
fig, ax = plt.subplots(figsize=(14,5))


ax.plot(df[df.index > pd.to_datetime("2024-01-01")].Volume, color='red', marker='.', linestyle='solid')

ax.set(xlabel='date', ylabel='Volume',
       title='plot Volume price  from (2024-01-01) to (2024-03-18) ')
ax.grid(True, linestyle='-.')
ax.tick_params(labelcolor='r', labelsize='medium', width=3)
